# %% [markdown]
# <a href="https://colab.research.google.com/github/Yab112/Competitive-Programming/blob/main/day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**analysis on dataset from TEDtallk**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 import pandas as pd

# %%
import matplotlib.pyplot  as plt

# %%
# %matplotlib inline

# %%
ted = pd.read_csv('drive/My Drive/yab/flight_csv_file/ted_main.csv')
ted.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
ted.shape
# Out:
# (2550, 17)

# %%
ted.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
 ted.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %% [markdown]
# ##**which talks provoke the most online dicussion**

# %%
ted.sort_values('comments').tail()
# Out:
#       comments                                        description  duration  \
# 1787      2673  Our consciousness is a fundamental aspect of o...      1117
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
#
#         event   film_date  languages       main_speaker  \
# 1787  TED2014  1395100800         33     David Chalmers
# 201   TED2008  1204070400         49  Jill Bolte Taylor
# 644   TED2010  1265846400         39         Sam Harris
# 0     TED2006  1140825600         60       Ken Robinson
# 96    TED2002  1012608000         42    Richard Dawkins
#
#                                                    name  num_speaker  \
# 1787  David Chalmers: How do you explain consciousness?            1
# ...

# %% [markdown]
# ### **row with comment 1750 provoke the most online discussion**
# but we do havea  problem  on this analysis like
#
# *   sub comments
# *   when they are posted

# %%
ted['comments_per_view'] = ted.comments/ted.views

# %%
ted.sort_values('comments_per_view')
# Out:
#       comments                                        description  duration  \
# 2534         2  What the astronauts felt when they saw Earth f...       725
# 2501         3  Meet Françoise Mouly, The New Yorker's art dir...       509
# 2542         3  In the century-old statues that occupy Cape To...       795
# 2528         3  Digital archaeologist Chance Coughenour is usi...       717
# 2494         7  Jimmy Lin is developing technologies to catch ...       730
# ...        ...                                                ...       ...
# 954       2492  Janet Echelman found her true voice as an arti...       566
# 694       1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
# 803        834  David Bismark demos a new system for voting th...       422
# 744        649  Hours before New York lawmakers rejected a key...       453
#
# ...

# %%
ted['views_per_comment'] = ted.views/ted.comments
ted.sort_values('views_per_comment').head()
# Out:
#      comments                                        description  duration  \
# 744       649  Hours before New York lawmakers rejected a key...       453
# 803       834  David Bismark demos a new system for voting th...       422
# 96       6404  Richard Dawkins urges all atheists to openly s...      1750
# 694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 954      2492  Janet Echelman found her true voice as an arti...       566
#
#                      event   film_date  languages           main_speaker  \
# 744  New York State Senate  1259712000          0        Diane J. Savino
# 803         TEDGlobal 2010  1279065600         36          David Bismark
# 96                 TED2002  1012608000         42        Richard Dawkins
# 694                TED2010  1265760000         32  Sharmeen Obaid-Chinoy
# 954                TED2011  1299110400         35         Janet Echelman
#
#                                                   name  num_speaker  \
# ...

# %% [markdown]
# ##**visualize the distribution of comments**

# %%
ted.comments.plot()
# Out:
# <Axes: >

# %% [markdown]
# a line graph

# %%
ted.comments.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ted[ted.comments > 1000].shape
# Out:
# (31, 19)

# %%
ted[ted.comments < 1000 ].comments.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ted.query('comments < 1000').comments.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
ted.loc[ted.comments < 1000,'comments'].plot(kind='hist',bins=34)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### **box plot**

# %% [markdown]
# **default bin is 10**

# %%
ted.loc[ted.comments < 1000,'comments'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # **plot the number of talks that took place each year**

# %%
ted.event
# Out:
# 879              TED2011
# 385              TED2009
# 1356      TEDGlobal 2012
# 1712    TED in the Field
# 2392    TEDxBeaconStreet
# 262              TED2004
# 810       TEDGlobal 2010
# 253       TEDGlobal 2007
# 125              TED2007
# 2114    TEDGlobal>Geneva
# 2258         TEDxBoulder
# 1481         TEDxCaltech
# Name: event, dtype: object

# %%
ted.event.sample(12)
# Out:
# 1926      TEDGlobal 2014
# 2078    TEDxThessaloniki
# 2064            TEDxPenn
# 228              TED2008
# 856        TEDWomen 2010
# 1537      TEDGlobal 2013
# 1479         TEDxCaltech
# 1528      TEDGlobal 2013
# 2519             TED2017
# 78               TED2003
# 981       TEDGlobal 2011
# 536       TEDGlobal 2009
# Name: event, dtype: object
